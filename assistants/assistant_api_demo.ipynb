# %% [markdown]
# # 最佳实践-基于Assistant API的旅游助手
#
#
# ## 1. 简介
# 本文介绍一个基于Assistant API实现的旅游助手最佳实践，通过智能调用各类函数实现，可以动态地实现各类旅游查询。在本示例代码中通过虚拟函数查询接口实现，支持查询多个旅游问题。
# 开发者可以替换成自己真实的API接口或复写其中的各类函数。
#
# ### 1.1. 依赖功能
# * Assistant API的基础API参数生成能力。
# * Assistant API的Function calling能力。
#
# ### 1.2. 前期准备
# * 已开通百炼服务：[开通阿里云百炼大模型服务产品](https://help.aliyun.com/document_detail/2586399.html?spm=a2c4g.2784257.0.i6)。
# * 已创建和获取API_KEY: [获取API-KEY](https://help.aliyun.com/document_detail/2712195.html)。
#
# ## 2. 实现代码
#
# ### 2.1. 设置环境变量
# 安装环境依赖，设置您的API-KEY，替换YOUR_DASHSCOPE_API_KEY为您自己的API key。

# %%
# 安装dashscope SDK。
# !pip3 install dashscope
# Out:
# Requirement already satisfied: dashscope in /Users/towardsun/miniconda3/envs/llama_index/lib/python3.10/site-packages (1.18.1)
# Requirement already satisfied: aiohttp in /Users/towardsun/miniconda3/envs/llama_index/lib/python3.10/site-packages (from dashscope) (3.9.5)
# Requirement already satisfied: requests in /Users/towardsun/miniconda3/envs/llama_index/lib/python3.10/site-packages (from dashscope) (2.31.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/towardsun/miniconda3/envs/llama_index/lib/python3.10/site-packages (from aiohttp->dashscope) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/towardsun/miniconda3/envs/llama_index/lib/python3.10/site-packages (from aiohttp->dashscope) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/towardsun/miniconda3/envs/llama_index/lib/python3.10/site-packages (from aiohttp->dashscope) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/towardsun/miniconda3/envs/llama_index/lib/python3.10/site-packages (from aiohttp->dashscope) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/towardsun/miniconda3/envs/llama_index/lib/python3.10/site-packages (from aiohttp->dashscope) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/towardsun/miniconda3/envs/llama_index/lib/python3.10/site-packages (from aiohttp->dashscope) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/towardsun/miniconda3/envs/llama_index/lib/python3.10/site-packages (from requests->dashscope) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/towardsun/miniconda3/envs/llama_index/lib/python3.10/site-packages (from requests->dashscope) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/towardsun/miniconda3/envs/llama_index/lib/python3.10/site-packages (from requests->dashscope) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/towardsun/miniconda3/envs/llama_index/lib/python3.10/site-packages (from requests->dashscope) (2024.2.2)

# %%
# 通过环境变量设置API-KEY
# %env DASHSCOPE_API_KEY=YOUR_API_KEY
# Out:
# env: DASHSCOPE_API_KEY=sk-0MOEpyHAR1

# %% [markdown]
# ### 2.2. 自定义函数接口
#
# 在tour assistant 中用到了多个自定义函数，开发者也可以根据自己的需求改写和增加相关函数。

# %%
destination = """
以下是一些推荐的旅游目的地：
1. 杭州（中国）
西湖：享有“人间天堂”的美誉，是中国最著名的自然景观之一。
灵隐寺：杭州最古老的寺庙之一，提供宁静的精神修养场所。
西溪湿地：天然的湿地生态区，可以近距离接触自然和野生生物。
2. 丽江（中国）
古城：保留了完好的历史建筑和纳西族文化，是一个不可多得的步行城市。
玉龙雪山：雄伟的山峰，提供滑雪和登山活动，景色壮观。
束河古镇：比丽江古城更为宁静的地方，适合品茶和静思。
3. 巴黎（法国）
埃菲尔铁塔：法国的象征，提供城市全景视角。
卢浮宫：世界上最大的艺术博物馆之一，收藏有《蒙娜丽莎》等珍贵艺术品。
凡尔赛宫：法国历史上的王宫，代表了欧洲花园和宫殿的顶峰。
4. 开普敦（南非）
桌山：通过缆车访问，顶部可俯瞰开普敦市和罗宾岛的壮丽景色。
好望角：著名的海角，为航海家提供的历史地标。
克尔斯滕博施植物园：世界上生物多样性最丰富的植物园之一。
"""

attraction = """
1. 丽江古城（大研古城）
特色：丽江古城是一个完美保存的古老纳西族城镇，以其石板路、流水和古桥而著名。无需购票即可进入，但维护古城的费用需购买一种维护费证书。
建议时间：建议早上开始您的游览以避开人群。
提示：晚上的古城特别迷人，有许多酒吧和咖啡馆可以享受。
2. 黑龙潭公园
特色：位于丽江古城北边，是欣赏玉龙雪山倒影的绝佳地点。
建议时间：上午或傍晚。
提示：入园免费，是拍照和散步的好地方。
3. 玉龙雪山
特色：这座壮观的雪山是丽江的标志性景点，您可以乘坐索道至冰川公园或牦牛坪。
建议时间：全天，但需留出足够的时间上山下山。
提示：高海拔可能引起高反，建议提前做好准备。
4. 白沙古镇
特色：相对于丽江古城，白沙古镇更加宁静，保留了更多传统纳西族文化。
建议时间：下午。
提示：可以尝试纳西族的传统手工艺品制作体验。
5. 束河古镇
特色：比丽江古城小而更为宁静，是了解纳西族文化的另一个好地点。
建议时间：晚上。
提示：束河古镇的夜生活相对平和，适合享受安静的晚餐。
"""

dining = """
餐饮建议
早餐：在丽江古城的小巷内尝试当地的酸奶和烧饵块。
午餐：在玉龙雪山下的餐厅尝试藏族或纳西族风味的菜肴。
晚餐：束河古镇有许多提供地道纳西菜的餐馆，推荐尝试纳西烤鱼。
"""

life_tips = """
旅行提示
衣着：丽江日夜温差大，即使在夏天也需携带厚外套。
高反：丽江海拔约2400米，部分人可能会有高原反应。建议游客到达后先适应一下高海拔环境，适当休息，多喝水，少进行剧烈运动。前往高海拔地区如玉龙雪山前，建议预防高原反应。
"""

local_customs = """
纳西族礼仪：

纳西族是丽江的主要民族，他们非常看重礼仪。与长辈交谈时，说话要礼貌且避免直视对方的眼睛，这是尊重的表现。
在参观纳西族家庭或参与当地活动时，接受主人提供的食物和饮料是礼貌的表现。
传统服饰：

当地人在特定节日或有重要活动时可能会穿着传统服装。游客可以租借纳西民族服饰拍照，但应保持尊重，不要对服饰进行任何不适当的处理。
节日和庆典：

参与当地节日如三月街（每年农历三月举行的大型集市和庆典）、庙会等，需遵守当地的规矩和传统，比如不大声喧哗、不随意涉足祭祀区域等。
"""

flight = """
航班号	机型	起飞时间	起飞机场	降落时间	降落机场	班期	餐食服务	票价
CA1469	32N	06:30	首都国际机场 T2	10:25	三义机场	每天	93%	¥1730 起
ZH1469	32N	06:30	首都国际机场 T2	10:25	三义机场	每天	93%	查看时价
JD5181	32Q	06:55	大兴国际机场	10:15	三义机场	每天	97%	¥630 起
CA1459	32N	16:20	首都国际机场 T2	20:15	三义机场	每天	97%	¥1150 起
ZH1459	32N	16:20	首都国际机场 T2	20:15	三义机场	每天	97%	查看时价
3U5234	737	16:55	大兴国际机场	20:05	三义机场	每天	-	¥2860 起
KN6139	737	16:55	大兴国际机场	20:05	三义机场	每天	-	查看时价
MU5716	737	16:55	大兴国际机场	20:05	三义机场	每天	-	¥900 起
3U5234	737	17:00	大兴国际机场	20:05	三义机场	每天	-	¥2860 起
KN6139	737	17:00	大兴国际机场	20:05	三义机场	每天	-	查看时价
MU5716	737	17:00	大兴国际机场	20:05	三义机场	每天	-	¥900 起
"""

# %%
def get_destination_recommendation(query):
    return destination


def get_attraction_recommendation(city):
    return attraction


def get_dining_recommendation(city):
    return dining


def get_life_tips(city):
    return life_tips


def get_local_customs(city):
    return local_customs


def get_current_date():
    return "今天"


def get_weather(location, date=""):
    if date == "":
        date = get_current_date()

    return date + "天气是" + "晴天"


def get_current_location():
    return "北京"


def get_path_recommendation(start, dest, recommendation=False):
    return "建议通过飞机从" + start + "到" + dest + "\n以下是航班信息\n" + flight

# %% [markdown]
# ### 2.3. 定义旅游助手Assistant
#
# 创建Assistant，定义工具说明，基于Assistant API的thread, message, 和run机制，运行assistant，整体接口与Open AI兼容。

# %%
import json
import sys
from http import HTTPStatus
from dashscope import Assistants, Messages, Runs, Threads

# %%
def create_assistant():
    # create assistant with information
    assistant = Assistants.create(
        model='qwen-max',
        name='smart helper',
        description='一个旅游助手，可以通过用户诉求，调用天气查询，路径推荐，当地餐厅推荐等帮助用户。',
        instructions='你是一个旅游助手，可以通过调用插件解决问题。插件例如，天气查询，路径推荐，当地餐厅推荐等，当你无法回答问题时应当结合插件回复进行回答。请根据插件结果适当丰富回复内容。',
        tools=[{
            'type': 'function',
            'function': {
                'name': '天气查询',
                'description': '用于查询天气的插件和函数',
                'parameters': {
                    'type': 'object',
                    'properties': {
                        'location': {
                            'type': 'str',
                            'description': '待查询的地点'
                        },
                        'date': {
                            'type': 'str',
                            'description': '待查询的具体日期'
                        }
                    },
                    'required': ['location', 'date']
                }
            }
        },
            {
                'type': 'function',
                'function': {
                    'name': '路径规划',
                    'description': '用于推荐出行和旅游的路径规划，包含查询路线，规划起点到终点的路线。也用于推荐最近最热门的旅游行程。',
                    'parameters': {
                        'type': 'object',
                        'properties': {
                            'start': {
                                'type': 'str',
                                'description': '待查询路径规划的出发点'
                            },
                            'dest': {
                                'type': 'str',
                                'description': '待查询路径规划的终点.'
                            },
                            'recommendation': {
                                'type': 'int',
                                'description': '用于控制是否随机推荐，用于在无法判断有路径规划终点时，设置为1，其他情况为0。此时会推荐最热门的旅游路线.'
                            }
                        },
                        'required': ['start', 'dest', 'recommendation']
                    }
                }
            },
            {
                'type': 'function',
                'function': {
                    'name': '获取目的地建议',
                    'description': '用于推荐最近热门的旅游目的地。',
                    'parameters': {
                        'type': 'object',
                        'properties': {
                            'query': {
                                'type': 'str',
                                'description': '可能需要的信息'
                            },
                        },
                        'required': ['query']
                    }
                }
            },
            {
                'type': 'function',
                'function': {
                    'name': '获取景点推荐',
                    'description': '用于推荐指定城市的旅游景点。',
                    'parameters': {
                        'type': 'object',
                        'properties': {
                            'city': {
                                'type': 'str',
                                'description': '城市名称'
                            },
                        },
                        'required': ['city']
                    }
                }
            },
            {
                'type': 'function',
                'function': {
                    'name': '获取餐饮推荐',
                    'description': '用于推荐指定城市的餐饮。',
                    'parameters': {
                        'type': 'object',
                        'properties': {
                            'city': {
                                'type': 'str',
                                'description': '城市名称'
                            },
                        },
                        'required': ['city']
                    }
                }
            },
            {
                'type': 'function',
                'function': {
                    'name': '获取旅行提示',
                    'description': '用于获取指定城市的旅行注意事项。',
                    'parameters': {
                        'type': 'object',
                        'properties': {
                            'city': {
                                'type': 'str',
                                'description': '城市名称'
                            },
                        },
                        'required': ['city']
                    }
                }
            },
            {
                'type': 'function',
                'function': {
                    'name': '获取当地风俗',
                    'description': '用于获取指定城市的当地风俗。',
                    'parameters': {
                        'type': 'object',
                        'properties': {
                            'city': {
                                'type': 'str',
                                'description': '城市名称'
                            },
                        },
                        'required': ['city']
                    }
                }
            },
        ],
    )

    return assistant

# %%
function_mapper = {
    "天气查询": get_weather,
    "路径规划": get_path_recommendation,
    "获取目的地建议": get_destination_recommendation,
    "获取景点推荐": get_attraction_recommendation,
    "获取餐饮推荐": get_dining_recommendation,
    "获取旅行提示": get_life_tips,
    "获取当地风俗": get_local_customs,
}


def verify_status_code(res):
    if res.status_code != HTTPStatus.OK:
        sys.exit(res.status_code)


def send_message(assistant, message='查询杭州天气'):
    print(f"Query: {message}")

    # create thread.
    # create a thread.
    thread = Threads.create()

    print(thread)

    # create a message.
    message = Messages.create(thread.id, content=message)
    # create run

    response = Runs.create(thread.id, assistant_id=assistant.id, stream=True)
    content_str = ""
    for event, run in response:
        if event == "thread.message.delta":
            content_str += run.delta.content.text.value
            print(content_str, flush=True)
    print(run)

    # # get run statue
    # run_status = Runs.get(run.id, thread_id=thread.id)
    # print(run_status)

    # wait for run completed or requires_action
    run_status = Runs.wait(run.id, thread_id=thread.id)
    # print(run_status)

    # if prompt input tool result, submit tool result.
    if run_status.required_action:

        f = run_status.required_action.submit_tool_outputs.tool_calls[0].function
        func_name = f['name']
        param = json.loads(f['arguments'])
        print(f)
        if func_name in function_mapper:
            output = function_mapper[func_name](**param)
        else:
            output = ""

        tool_outputs = [{
            'output':
                output
        }]
        responses = Runs.submit_tool_outputs(run.id,
                                             thread_id=thread.id,
                                             tool_outputs=tool_outputs,
                                             stream=True)
        content_str = ""
        for event, run in responses:
            if event == "thread.message.delta":
                content_str += run.delta.content.text.value
                print(content_str, flush=True)

        # should wait for run completed
        run_status = Runs.wait(run.id, thread_id=thread.id)
        # print(run_status)
        verify_status_code(run_status)

    run_status = Runs.get(run.id, thread_id=thread.id)
    print(run_status)
    # verify_status_code(run_status)

    # get the thread messages.
    msgs = Messages.list(thread.id)
    # print(msgs)
    # print(json.dumps(msgs, default=lambda o: o.__dict__, sort_keys=True, indent=4))

    print("运行结果:")
    for message in msgs['data'][::-1]:
        print("content: ", message['content'][0]['text']['value'])
    print("\n")

# %% [markdown]
# ### 2.4. 运行Assistant

# %%
trip_agent = create_assistant()

send_message(assistant=trip_agent, message="请一句话概括爱因斯坦的成就？")
# Out:
# Query: 请一句话概括爱因斯坦的成就？
# {'id': 'thread_122b4540-d4ff-475b-ac50-ca075ca93d50', 'object': 'thread', 'created_at': 1718852222486, 'metadata': {}, 'request_id': 'c1c17f89-b488-970a-939f-885111154c6c', 'status_code': 200}
# 爱
# 爱因
# 爱因斯坦
# 爱因斯坦提出了相对论，彻底
# 爱因斯坦提出了相对论，彻底改变了我们对时间、空间、重
# 爱因斯坦提出了相对论，彻底改变了我们对时间、空间、重力的理解，为现代物理学奠定了基础
# 爱因斯坦提出了相对论，彻底改变了我们对时间、空间、重力的理解，为现代物理学奠定了基础。
# 爱因斯坦提出了相对论，彻底改变了我们对时间、空间、重力的理解，为现代物理学奠定了基础。
# {'tools': [{'function': {'name': '天气查询', 'description': '用于查询天气的插件和函数', 'parameters': {'type': 'object', 'properties': {'location': {'type': 'str', 'description': '待查询的地点'}, 'date': {'type': 'str', 'description': '待查询的具体日期'}}, 'required': ['location', 'date']}}, 'type': 'function'}, {'function': {'name': '路径规划', 'description': '用于推荐出行和旅游的路径规划，包含查询路线，规划起点到终点的路线。也用于推荐最近最热门的旅游行程。', 'parameters': {'type': 'object', 'properties': {'start': {'type': 'str', 'description': '待查询路径规划的出发点'}, 'dest': {'type': 'str', 'description': '待查询路径规划的终点.'}, 'recommendation': {'type': 'int', 'description': '用于控制是否随机推荐，用于在无法判断有路径规划终点时，设置为1，其他情况为0。此时会推荐最热门的旅游路线.'}}, 'required': ['start', 'dest', 'recommendation']}}, 'type': 'function'}, {'function': {'name': '获取目的地建议', 'description': '用于推荐最近热门的旅游目的地。', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'str', 'description': '可能需要的信息'}}, 'required': ['query']}}, 'type': 'function'}, {'function': {'name': '获取景点推荐', 'description': '用于推荐指定城市的旅游景点。', 'parameters': {'type': 'object', 'properties': {'city': {'type': 'str', 'description': '城市名称'}}, 'required': ['city']}}, 'type': 'function'}, {'function': {'name': '获取餐饮推荐', 'description': '用于推荐指定城市的餐饮。', 'parameters': {'type': 'object', 'properties': {'city': {'type': 'str', 'description': '城市名称'}}, 'required': ['city']}}, 'type': 'function'}, {'function': {'name': '获取旅行提示', 'description': '用于获取指定城市的旅行注意事项。', 'parameters': {'type': 'object', 'properties': {'city': {'type': 'str', 'description': '城市名称'}}, 'required': ['city']}}, 'type': 'function'}, {'function': {'name': '获取当地风俗', 'description': '用于获取指定城市的当地风俗。', 'parameters': {'type': 'object', 'properties': {'city': {'type': 'str', 'description': '城市名称'}}, 'required': ['city']}}, 'type': 'function'}], 'required_action': None, 'id': 'run_f0e72d0e-e1bf-425a-8052-a11532bd7bed', 'object': 'thread.run', 'created_at': 1718852223057, 'thread_id': 'thread_122b4540-d4ff-475b-ac50-ca075ca93d50', 'assistant_id': 'asst_46c11acb-ea00-468b-9d42-3dd0fb3b768f', 'status': 'completed', 'last_error': None, 'expires_at': None, 'started_at': None, 'cancelled_at': None, 'failed_at': None, 'completed_at': 1718852226984, 'model': 'qwen-max', 'instructions': '你是一个旅游助手，可以通过调用插件解决问题。插件例如，天气查询，路径推荐，当地餐厅推荐等，当你无法回答问题时应当结合插件回复进行回答。请根据插件结果适当丰富回复内容。', 'file_ids': [], 'metadata': {}, 'usage': {'input_tokens': 801, 'output_tokens': 25, 'total_tokens': 826}, 'temperature': None, 'top_p': None, 'top_k': None, 'max_tokens': None, 'truncation_strategy': None, 'tool_choice': 'auto', 'request_id': 'bface19e-cea5-95ef-b8fa-66e8fd4d3d5b', 'status_code': 200}
# {
#     "assistant_id": "asst_46c11acb-ea00-468b-9d42-3dd0fb3b768f",
#     "cancelled_at": null,
#     "completed_at": 1718852226984,
#     "created_at": 1718852223057,
#     "expires_at": null,
#     "failed_at": null,
#     "file_ids": [],
#     "id": "run_f0e72d0e-e1bf-425a-8052-a11532bd7bed",
#     "instructions": "\u4f60\u662f\u4e00\u4e2a\u65c5\u6e38\u52a9\u624b\uff0c\u53ef\u4ee5\u901a\u8fc7\u8c03\u7528\u63d2\u4ef6\u89e3\u51b3\u95ee\u9898\u3002\u63d2\u4ef6\u4f8b\u5982\uff0c\u5929\u6c14\u67e5\u8be2\uff0c\u8def\u5f84\u63a8\u8350\uff0c\u5f53\u5730\u9910\u5385\u63a8\u8350\u7b49\uff0c\u5f53\u4f60\u65e0\u6cd5\u56de\u7b54\u95ee\u9898\u65f6\u5e94\u5f53\u7ed3\u5408\u63d2\u4ef6\u56de\u590d\u8fdb\u884c\u56de\u7b54\u3002\u8bf7\u6839\u636e\u63d2\u4ef6\u7ed3\u679c\u9002\u5f53\u4e30\u5bcc\u56de\u590d\u5185\u5bb9\u3002",
#     "last_error": null,
#     "max_tokens": null,
#     "metadata": {},
#     "model": "qwen-max",
#     "object": "thread.run",
#     "request_id": "c7cc00e1-47ff-94e2-9867-c2e4db6ae0dc",
#     "required_action": null,
#     "started_at": null,
#     "status": "completed",
#     "status_code": 200,
#     "temperature": null,
#     "thread_id": "thread_122b4540-d4ff-475b-ac50-ca075ca93d50",
#     "tool_choice": "auto",
#     "tools": [
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u67e5\u8be2\u5929\u6c14\u7684\u63d2\u4ef6\u548c\u51fd\u6570",
#                 "name": "\u5929\u6c14\u67e5\u8be2",
#                 "parameters": {
#                     "properties": {
#                         "date": {
#                             "description": "\u5f85\u67e5\u8be2\u7684\u5177\u4f53\u65e5\u671f",
#                             "type": "str"
#                         },
#                         "location": {
#                             "description": "\u5f85\u67e5\u8be2\u7684\u5730\u70b9",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "location",
#                         "date"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         },
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u63a8\u8350\u51fa\u884c\u548c\u65c5\u6e38\u7684\u8def\u5f84\u89c4\u5212\uff0c\u5305\u542b\u67e5\u8be2\u8def\u7ebf\uff0c\u89c4\u5212\u8d77\u70b9\u5230\u7ec8\u70b9\u7684\u8def\u7ebf\u3002\u4e5f\u7528\u4e8e\u63a8\u8350\u6700\u8fd1\u6700\u70ed\u95e8\u7684\u65c5\u6e38\u884c\u7a0b\u3002",
#                 "name": "\u8def\u5f84\u89c4\u5212",
#                 "parameters": {
#                     "properties": {
#                         "dest": {
#                             "description": "\u5f85\u67e5\u8be2\u8def\u5f84\u89c4\u5212\u7684\u7ec8\u70b9.",
#                             "type": "str"
#                         },
#                         "recommendation": {
#                             "description": "\u7528\u4e8e\u63a7\u5236\u662f\u5426\u968f\u673a\u63a8\u8350\uff0c\u7528\u4e8e\u5728\u65e0\u6cd5\u5224\u65ad\u6709\u8def\u5f84\u89c4\u5212\u7ec8\u70b9\u65f6\uff0c\u8bbe\u7f6e\u4e3a1\uff0c\u5176\u4ed6\u60c5\u51b5\u4e3a0\u3002\u6b64\u65f6\u4f1a\u63a8\u8350\u6700\u70ed\u95e8\u7684\u65c5\u6e38\u8def\u7ebf.",
#                             "type": "int"
#                         },
#                         "start": {
#                             "description": "\u5f85\u67e5\u8be2\u8def\u5f84\u89c4\u5212\u7684\u51fa\u53d1\u70b9",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "start",
#                         "dest",
#                         "recommendation"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         },
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u63a8\u8350\u6700\u8fd1\u70ed\u95e8\u7684\u65c5\u6e38\u76ee\u7684\u5730\u3002",
#                 "name": "\u83b7\u53d6\u76ee\u7684\u5730\u5efa\u8bae",
#                 "parameters": {
#                     "properties": {
#                         "query": {
#                             "description": "\u53ef\u80fd\u9700\u8981\u7684\u4fe1\u606f",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "query"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         },
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u63a8\u8350\u6307\u5b9a\u57ce\u5e02\u7684\u65c5\u6e38\u666f\u70b9\u3002",
#                 "name": "\u83b7\u53d6\u666f\u70b9\u63a8\u8350",
#                 "parameters": {
#                     "properties": {
#                         "city": {
#                             "description": "\u57ce\u5e02\u540d\u79f0",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "city"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         },
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u63a8\u8350\u6307\u5b9a\u57ce\u5e02\u7684\u9910\u996e\u3002",
#                 "name": "\u83b7\u53d6\u9910\u996e\u63a8\u8350",
#                 "parameters": {
#                     "properties": {
#                         "city": {
#                             "description": "\u57ce\u5e02\u540d\u79f0",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "city"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         },
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u83b7\u53d6\u6307\u5b9a\u57ce\u5e02\u7684\u65c5\u884c\u6ce8\u610f\u4e8b\u9879\u3002",
#                 "name": "\u83b7\u53d6\u65c5\u884c\u63d0\u793a",
#                 "parameters": {
#                     "properties": {
#                         "city": {
#                             "description": "\u57ce\u5e02\u540d\u79f0",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "city"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         },
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u83b7\u53d6\u6307\u5b9a\u57ce\u5e02\u7684\u5f53\u5730\u98ce\u4fd7\u3002",
#                 "name": "\u83b7\u53d6\u5f53\u5730\u98ce\u4fd7",
#                 "parameters": {
#                     "properties": {
#                         "city": {
#                             "description": "\u57ce\u5e02\u540d\u79f0",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "city"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         }
#     ],
#     "top_k": null,
#     "top_p": null,
#     "truncation_strategy": null,
#     "usage": {
#         "input_tokens": 801,
#         "output_tokens": 25,
#         "total_tokens": 826
#     }
# }
# {'tools': [{'function': {'name': '天气查询', 'description': '用于查询天气的插件和函数', 'parameters': {'type': 'object', 'properties': {'location': {'type': 'str', 'description': '待查询的地点'}, 'date': {'type': 'str', 'description': '待查询的具体日期'}}, 'required': ['location', 'date']}}, 'type': 'function'}, {'function': {'name': '路径规划', 'description': '用于推荐出行和旅游的路径规划，包含查询路线，规划起点到终点的路线。也用于推荐最近最热门的旅游行程。', 'parameters': {'type': 'object', 'properties': {'start': {'type': 'str', 'description': '待查询路径规划的出发点'}, 'dest': {'type': 'str', 'description': '待查询路径规划的终点.'}, 'recommendation': {'type': 'int', 'description': '用于控制是否随机推荐，用于在无法判断有路径规划终点时，设置为1，其他情况为0。此时会推荐最热门的旅游路线.'}}, 'required': ['start', 'dest', 'recommendation']}}, 'type': 'function'}, {'function': {'name': '获取目的地建议', 'description': '用于推荐最近热门的旅游目的地。', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'str', 'description': '可能需要的信息'}}, 'required': ['query']}}, 'type': 'function'}, {'function': {'name': '获取景点推荐', 'description': '用于推荐指定城市的旅游景点。', 'parameters': {'type': 'object', 'properties': {'city': {'type': 'str', 'description': '城市名称'}}, 'required': ['city']}}, 'type': 'function'}, {'function': {'name': '获取餐饮推荐', 'description': '用于推荐指定城市的餐饮。', 'parameters': {'type': 'object', 'properties': {'city': {'type': 'str', 'description': '城市名称'}}, 'required': ['city']}}, 'type': 'function'}, {'function': {'name': '获取旅行提示', 'description': '用于获取指定城市的旅行注意事项。', 'parameters': {'type': 'object', 'properties': {'city': {'type': 'str', 'description': '城市名称'}}, 'required': ['city']}}, 'type': 'function'}, {'function': {'name': '获取当地风俗', 'description': '用于获取指定城市的当地风俗。', 'parameters': {'type': 'object', 'properties': {'city': {'type': 'str', 'description': '城市名称'}}, 'required': ['city']}}, 'type': 'function'}], 'required_action': None, 'id': 'run_f0e72d0e-e1bf-425a-8052-a11532bd7bed', 'object': 'thread.run', 'created_at': 1718852223057, 'thread_id': 'thread_122b4540-d4ff-475b-ac50-ca075ca93d50', 'assistant_id': 'asst_46c11acb-ea00-468b-9d42-3dd0fb3b768f', 'status': 'completed', 'last_error': None, 'expires_at': None, 'started_at': None, 'cancelled_at': None, 'failed_at': None, 'completed_at': 1718852226984, 'model': 'qwen-max', 'instructions': '你是一个旅游助手，可以通过调用插件解决问题。插件例如，天气查询，路径推荐，当地餐厅推荐等，当你无法回答问题时应当结合插件回复进行回答。请根据插件结果适当丰富回复内容。', 'file_ids': [], 'metadata': {}, 'usage': {'input_tokens': 801, 'output_tokens': 25, 'total_tokens': 826}, 'temperature': None, 'top_p': None, 'top_k': None, 'max_tokens': None, 'truncation_strategy': None, 'tool_choice': 'auto', 'request_id': '34559129-aa7d-915a-8065-f5bb0b7122be', 'status_code': 200}
# 运行结果:
# content:  请一句话概括爱因斯坦的成就？
# content:  爱因斯坦提出了相对论，彻底改变了我们对时间、空间、重力的理解，为现代物理学奠定了基础。

# %%
send_message(assistant=trip_agent, message="丽江天气怎么样？")
# Out:
# Query: 丽江天气怎么样？
# {'id': 'thread_09264327-1497-459a-8925-3a19a9081b27', 'object': 'thread', 'created_at': 1718852254664, 'metadata': {}, 'request_id': 'f6275962-ae96-92fd-a1eb-6ee958b86448', 'status_code': 200}
# {'tools': [{'function': {'name': '天气查询', 'description': '用于查询天气的插件和函数', 'parameters': {'type': 'object', 'properties': {'location': {'type': 'str', 'description': '待查询的地点'}, 'date': {'type': 'str', 'description': '待查询的具体日期'}}, 'required': ['location', 'date']}}, 'type': 'function'}, {'function': {'name': '路径规划', 'description': '用于推荐出行和旅游的路径规划，包含查询路线，规划起点到终点的路线。也用于推荐最近最热门的旅游行程。', 'parameters': {'type': 'object', 'properties': {'start': {'type': 'str', 'description': '待查询路径规划的出发点'}, 'dest': {'type': 'str', 'description': '待查询路径规划的终点.'}, 'recommendation': {'type': 'int', 'description': '用于控制是否随机推荐，用于在无法判断有路径规划终点时，设置为1，其他情况为0。此时会推荐最热门的旅游路线.'}}, 'required': ['start', 'dest', 'recommendation']}}, 'type': 'function'}, {'function': {'name': '获取目的地建议', 'description': '用于推荐最近热门的旅游目的地。', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'str', 'description': '可能需要的信息'}}, 'required': ['query']}}, 'type': 'function'}, {'function': {'name': '获取景点推荐', 'description': '用于推荐指定城市的旅游景点。', 'parameters': {'type': 'object', 'properties': {'city': {'type': 'str', 'description': '城市名称'}}, 'required': ['city']}}, 'type': 'function'}, {'function': {'name': '获取餐饮推荐', 'description': '用于推荐指定城市的餐饮。', 'parameters': {'type': 'object', 'properties': {'city': {'type': 'str', 'description': '城市名称'}}, 'required': ['city']}}, 'type': 'function'}, {'function': {'name': '获取旅行提示', 'description': '用于获取指定城市的旅行注意事项。', 'parameters': {'type': 'object', 'properties': {'city': {'type': 'str', 'description': '城市名称'}}, 'required': ['city']}}, 'type': 'function'}, {'function': {'name': '获取当地风俗', 'description': '用于获取指定城市的当地风俗。', 'parameters': {'type': 'object', 'properties': {'city': {'type': 'str', 'description': '城市名称'}}, 'required': ['city']}}, 'type': 'function'}], 'required_action': {'submit_tool_outputs': {'tool_calls': [{'id': '', 'function': {'arguments': '{"location": "丽江", "date": "2023-04-07"}', 'name': '天气查询', 'output': None}, 'type': 'function'}]}, 'type': 'submit_tool_outputs'}, 'id': 'run_136ab81d-753b-4d22-bd39-8e47fc92bc74', 'object': 'thread.run', 'created_at': 1718852255073, 'thread_id': 'thread_09264327-1497-459a-8925-3a19a9081b27', 'assistant_id': 'asst_46c11acb-ea00-468b-9d42-3dd0fb3b768f', 'status': 'requires_action', 'last_error': None, 'expires_at': None, 'started_at': None, 'cancelled_at': None, 'failed_at': None, 'completed_at': 1718852258981, 'model': 'qwen-max', 'instructions': '你是一个旅游助手，可以通过调用插件解决问题。插件例如，天气查询，路径推荐，当地餐厅推荐等，当你无法回答问题时应当结合插件回复进行回答。请根据插件结果适当丰富回复内容。', 'file_ids': [], 'metadata': {}, 'usage': None, 'temperature': None, 'top_p': None, 'top_k': None, 'max_tokens': None, 'truncation_strategy': None, 'tool_choice': 'auto', 'request_id': '0e4765d7-350b-9a8c-b6af-f45d3a9fb695', 'status_code': 200}
# {
#     "assistant_id": "asst_46c11acb-ea00-468b-9d42-3dd0fb3b768f",
#     "cancelled_at": null,
#     "completed_at": 1718852258981,
#     "created_at": 1718852255073,
#     "expires_at": null,
#     "failed_at": null,
#     "file_ids": [],
#     "id": "run_136ab81d-753b-4d22-bd39-8e47fc92bc74",
#     "instructions": "\u4f60\u662f\u4e00\u4e2a\u65c5\u6e38\u52a9\u624b\uff0c\u53ef\u4ee5\u901a\u8fc7\u8c03\u7528\u63d2\u4ef6\u89e3\u51b3\u95ee\u9898\u3002\u63d2\u4ef6\u4f8b\u5982\uff0c\u5929\u6c14\u67e5\u8be2\uff0c\u8def\u5f84\u63a8\u8350\uff0c\u5f53\u5730\u9910\u5385\u63a8\u8350\u7b49\uff0c\u5f53\u4f60\u65e0\u6cd5\u56de\u7b54\u95ee\u9898\u65f6\u5e94\u5f53\u7ed3\u5408\u63d2\u4ef6\u56de\u590d\u8fdb\u884c\u56de\u7b54\u3002\u8bf7\u6839\u636e\u63d2\u4ef6\u7ed3\u679c\u9002\u5f53\u4e30\u5bcc\u56de\u590d\u5185\u5bb9\u3002",
#     "last_error": null,
#     "max_tokens": null,
#     "metadata": {},
#     "model": "qwen-max",
#     "object": "thread.run",
#     "request_id": "9fac4c74-565a-9aa0-be3c-9c4b97b72c7f",
#     "required_action": {
#         "submit_tool_outputs": {
#             "tool_calls": [
#                 {
#                     "function": {
#                         "arguments": "{\"location\": \"\u4e3d\u6c5f\", \"date\": \"2023-04-07\"}",
#                         "name": "\u5929\u6c14\u67e5\u8be2"
#                     },
#                     "id": "",
#                     "type": "function"
#                 }
#             ]
#         },
#         "type": "submit_tool_outputs"
#     },
#     "started_at": null,
#     "status": "requires_action",
#     "status_code": 200,
#     "temperature": null,
#     "thread_id": "thread_09264327-1497-459a-8925-3a19a9081b27",
#     "tool_choice": "auto",
#     "tools": [
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u67e5\u8be2\u5929\u6c14\u7684\u63d2\u4ef6\u548c\u51fd\u6570",
#                 "name": "\u5929\u6c14\u67e5\u8be2",
#                 "parameters": {
#                     "properties": {
#                         "date": {
#                             "description": "\u5f85\u67e5\u8be2\u7684\u5177\u4f53\u65e5\u671f",
#                             "type": "str"
#                         },
#                         "location": {
#                             "description": "\u5f85\u67e5\u8be2\u7684\u5730\u70b9",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "location",
#                         "date"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         },
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u63a8\u8350\u51fa\u884c\u548c\u65c5\u6e38\u7684\u8def\u5f84\u89c4\u5212\uff0c\u5305\u542b\u67e5\u8be2\u8def\u7ebf\uff0c\u89c4\u5212\u8d77\u70b9\u5230\u7ec8\u70b9\u7684\u8def\u7ebf\u3002\u4e5f\u7528\u4e8e\u63a8\u8350\u6700\u8fd1\u6700\u70ed\u95e8\u7684\u65c5\u6e38\u884c\u7a0b\u3002",
#                 "name": "\u8def\u5f84\u89c4\u5212",
#                 "parameters": {
#                     "properties": {
#                         "dest": {
#                             "description": "\u5f85\u67e5\u8be2\u8def\u5f84\u89c4\u5212\u7684\u7ec8\u70b9.",
#                             "type": "str"
#                         },
#                         "recommendation": {
#                             "description": "\u7528\u4e8e\u63a7\u5236\u662f\u5426\u968f\u673a\u63a8\u8350\uff0c\u7528\u4e8e\u5728\u65e0\u6cd5\u5224\u65ad\u6709\u8def\u5f84\u89c4\u5212\u7ec8\u70b9\u65f6\uff0c\u8bbe\u7f6e\u4e3a1\uff0c\u5176\u4ed6\u60c5\u51b5\u4e3a0\u3002\u6b64\u65f6\u4f1a\u63a8\u8350\u6700\u70ed\u95e8\u7684\u65c5\u6e38\u8def\u7ebf.",
#                             "type": "int"
#                         },
#                         "start": {
#                             "description": "\u5f85\u67e5\u8be2\u8def\u5f84\u89c4\u5212\u7684\u51fa\u53d1\u70b9",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "start",
#                         "dest",
#                         "recommendation"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         },
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u63a8\u8350\u6700\u8fd1\u70ed\u95e8\u7684\u65c5\u6e38\u76ee\u7684\u5730\u3002",
#                 "name": "\u83b7\u53d6\u76ee\u7684\u5730\u5efa\u8bae",
#                 "parameters": {
#                     "properties": {
#                         "query": {
#                             "description": "\u53ef\u80fd\u9700\u8981\u7684\u4fe1\u606f",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "query"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         },
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u63a8\u8350\u6307\u5b9a\u57ce\u5e02\u7684\u65c5\u6e38\u666f\u70b9\u3002",
#                 "name": "\u83b7\u53d6\u666f\u70b9\u63a8\u8350",
#                 "parameters": {
#                     "properties": {
#                         "city": {
#                             "description": "\u57ce\u5e02\u540d\u79f0",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "city"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         },
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u63a8\u8350\u6307\u5b9a\u57ce\u5e02\u7684\u9910\u996e\u3002",
#                 "name": "\u83b7\u53d6\u9910\u996e\u63a8\u8350",
#                 "parameters": {
#                     "properties": {
#                         "city": {
#                             "description": "\u57ce\u5e02\u540d\u79f0",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "city"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         },
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u83b7\u53d6\u6307\u5b9a\u57ce\u5e02\u7684\u65c5\u884c\u6ce8\u610f\u4e8b\u9879\u3002",
#                 "name": "\u83b7\u53d6\u65c5\u884c\u63d0\u793a",
#                 "parameters": {
#                     "properties": {
#                         "city": {
#                             "description": "\u57ce\u5e02\u540d\u79f0",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "city"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         },
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u83b7\u53d6\u6307\u5b9a\u57ce\u5e02\u7684\u5f53\u5730\u98ce\u4fd7\u3002",
#                 "name": "\u83b7\u53d6\u5f53\u5730\u98ce\u4fd7",
#                 "parameters": {
#                     "properties": {
#                         "city": {
#                             "description": "\u57ce\u5e02\u540d\u79f0",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "city"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         }
#     ],
#     "top_k": null,
#     "top_p": null,
#     "truncation_strategy": null,
#     "usage": null
# }
# {'name': '天气查询', 'arguments': '{"location": "丽江", "date": "2023-04-07"}', 'output': None}
# 丽江
# 丽江2023年
# 丽江2023年4月7日的天气预报是
# 丽江2023年4月7日的天气预报是晴朗的。如果您计划外出，
# 丽江2023年4月7日的天气预报是晴朗的。如果您计划外出，记得享受那里的明媚阳光，同时
# 丽江2023年4月7日的天气预报是晴朗的。如果您计划外出，记得享受那里的明媚阳光，同时也要做好防晒措施哦。
# 丽江2023年4月7日的天气预报是晴朗的。如果您计划外出，记得享受那里的明媚阳光，同时也要做好防晒措施哦。
# {
#     "assistant_id": "asst_46c11acb-ea00-468b-9d42-3dd0fb3b768f",
#     "cancelled_at": null,
#     "completed_at": 1718852262981,
#     "created_at": 1718852255073,
#     "expires_at": null,
#     "failed_at": null,
#     "file_ids": [],
#     "id": "run_136ab81d-753b-4d22-bd39-8e47fc92bc74",
#     "instructions": "\u4f60\u662f\u4e00\u4e2a\u65c5\u6e38\u52a9\u624b\uff0c\u53ef\u4ee5\u901a\u8fc7\u8c03\u7528\u63d2\u4ef6\u89e3\u51b3\u95ee\u9898\u3002\u63d2\u4ef6\u4f8b\u5982\uff0c\u5929\u6c14\u67e5\u8be2\uff0c\u8def\u5f84\u63a8\u8350\uff0c\u5f53\u5730\u9910\u5385\u63a8\u8350\u7b49\uff0c\u5f53\u4f60\u65e0\u6cd5\u56de\u7b54\u95ee\u9898\u65f6\u5e94\u5f53\u7ed3\u5408\u63d2\u4ef6\u56de\u590d\u8fdb\u884c\u56de\u7b54\u3002\u8bf7\u6839\u636e\u63d2\u4ef6\u7ed3\u679c\u9002\u5f53\u4e30\u5bcc\u56de\u590d\u5185\u5bb9\u3002",
#     "last_error": null,
#     "max_tokens": null,
#     "metadata": {},
#     "model": "qwen-max",
#     "object": "thread.run",
#     "request_id": "04625915-fbe6-9d4a-87ce-a65dc9fe059a",
#     "required_action": null,
#     "started_at": null,
#     "status": "completed",
#     "status_code": 200,
#     "temperature": null,
#     "thread_id": "thread_09264327-1497-459a-8925-3a19a9081b27",
#     "tool_choice": "auto",
#     "tools": [
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u67e5\u8be2\u5929\u6c14\u7684\u63d2\u4ef6\u548c\u51fd\u6570",
#                 "name": "\u5929\u6c14\u67e5\u8be2",
#                 "parameters": {
#                     "properties": {
#                         "date": {
#                             "description": "\u5f85\u67e5\u8be2\u7684\u5177\u4f53\u65e5\u671f",
#                             "type": "str"
#                         },
#                         "location": {
#                             "description": "\u5f85\u67e5\u8be2\u7684\u5730\u70b9",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "location",
#                         "date"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         },
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u63a8\u8350\u51fa\u884c\u548c\u65c5\u6e38\u7684\u8def\u5f84\u89c4\u5212\uff0c\u5305\u542b\u67e5\u8be2\u8def\u7ebf\uff0c\u89c4\u5212\u8d77\u70b9\u5230\u7ec8\u70b9\u7684\u8def\u7ebf\u3002\u4e5f\u7528\u4e8e\u63a8\u8350\u6700\u8fd1\u6700\u70ed\u95e8\u7684\u65c5\u6e38\u884c\u7a0b\u3002",
#                 "name": "\u8def\u5f84\u89c4\u5212",
#                 "parameters": {
#                     "properties": {
#                         "dest": {
#                             "description": "\u5f85\u67e5\u8be2\u8def\u5f84\u89c4\u5212\u7684\u7ec8\u70b9.",
#                             "type": "str"
#                         },
#                         "recommendation": {
#                             "description": "\u7528\u4e8e\u63a7\u5236\u662f\u5426\u968f\u673a\u63a8\u8350\uff0c\u7528\u4e8e\u5728\u65e0\u6cd5\u5224\u65ad\u6709\u8def\u5f84\u89c4\u5212\u7ec8\u70b9\u65f6\uff0c\u8bbe\u7f6e\u4e3a1\uff0c\u5176\u4ed6\u60c5\u51b5\u4e3a0\u3002\u6b64\u65f6\u4f1a\u63a8\u8350\u6700\u70ed\u95e8\u7684\u65c5\u6e38\u8def\u7ebf.",
#                             "type": "int"
#                         },
#                         "start": {
#                             "description": "\u5f85\u67e5\u8be2\u8def\u5f84\u89c4\u5212\u7684\u51fa\u53d1\u70b9",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "start",
#                         "dest",
#                         "recommendation"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         },
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u63a8\u8350\u6700\u8fd1\u70ed\u95e8\u7684\u65c5\u6e38\u76ee\u7684\u5730\u3002",
#                 "name": "\u83b7\u53d6\u76ee\u7684\u5730\u5efa\u8bae",
#                 "parameters": {
#                     "properties": {
#                         "query": {
#                             "description": "\u53ef\u80fd\u9700\u8981\u7684\u4fe1\u606f",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "query"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         },
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u63a8\u8350\u6307\u5b9a\u57ce\u5e02\u7684\u65c5\u6e38\u666f\u70b9\u3002",
#                 "name": "\u83b7\u53d6\u666f\u70b9\u63a8\u8350",
#                 "parameters": {
#                     "properties": {
#                         "city": {
#                             "description": "\u57ce\u5e02\u540d\u79f0",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "city"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         },
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u63a8\u8350\u6307\u5b9a\u57ce\u5e02\u7684\u9910\u996e\u3002",
#                 "name": "\u83b7\u53d6\u9910\u996e\u63a8\u8350",
#                 "parameters": {
#                     "properties": {
#                         "city": {
#                             "description": "\u57ce\u5e02\u540d\u79f0",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "city"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         },
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u83b7\u53d6\u6307\u5b9a\u57ce\u5e02\u7684\u65c5\u884c\u6ce8\u610f\u4e8b\u9879\u3002",
#                 "name": "\u83b7\u53d6\u65c5\u884c\u63d0\u793a",
#                 "parameters": {
#                     "properties": {
#                         "city": {
#                             "description": "\u57ce\u5e02\u540d\u79f0",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "city"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         },
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u83b7\u53d6\u6307\u5b9a\u57ce\u5e02\u7684\u5f53\u5730\u98ce\u4fd7\u3002",
#                 "name": "\u83b7\u53d6\u5f53\u5730\u98ce\u4fd7",
#                 "parameters": {
#                     "properties": {
#                         "city": {
#                             "description": "\u57ce\u5e02\u540d\u79f0",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "city"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         }
#     ],
#     "top_k": null,
#     "top_p": null,
#     "truncation_strategy": null,
#     "usage": {
#         "input_tokens": 853,
#         "output_tokens": 38,
#         "total_tokens": 891
#     }
# }
# {'tools': [{'function': {'name': '天气查询', 'description': '用于查询天气的插件和函数', 'parameters': {'type': 'object', 'properties': {'location': {'type': 'str', 'description': '待查询的地点'}, 'date': {'type': 'str', 'description': '待查询的具体日期'}}, 'required': ['location', 'date']}}, 'type': 'function'}, {'function': {'name': '路径规划', 'description': '用于推荐出行和旅游的路径规划，包含查询路线，规划起点到终点的路线。也用于推荐最近最热门的旅游行程。', 'parameters': {'type': 'object', 'properties': {'start': {'type': 'str', 'description': '待查询路径规划的出发点'}, 'dest': {'type': 'str', 'description': '待查询路径规划的终点.'}, 'recommendation': {'type': 'int', 'description': '用于控制是否随机推荐，用于在无法判断有路径规划终点时，设置为1，其他情况为0。此时会推荐最热门的旅游路线.'}}, 'required': ['start', 'dest', 'recommendation']}}, 'type': 'function'}, {'function': {'name': '获取目的地建议', 'description': '用于推荐最近热门的旅游目的地。', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'str', 'description': '可能需要的信息'}}, 'required': ['query']}}, 'type': 'function'}, {'function': {'name': '获取景点推荐', 'description': '用于推荐指定城市的旅游景点。', 'parameters': {'type': 'object', 'properties': {'city': {'type': 'str', 'description': '城市名称'}}, 'required': ['city']}}, 'type': 'function'}, {'function': {'name': '获取餐饮推荐', 'description': '用于推荐指定城市的餐饮。', 'parameters': {'type': 'object', 'properties': {'city': {'type': 'str', 'description': '城市名称'}}, 'required': ['city']}}, 'type': 'function'}, {'function': {'name': '获取旅行提示', 'description': '用于获取指定城市的旅行注意事项。', 'parameters': {'type': 'object', 'properties': {'city': {'type': 'str', 'description': '城市名称'}}, 'required': ['city']}}, 'type': 'function'}, {'function': {'name': '获取当地风俗', 'description': '用于获取指定城市的当地风俗。', 'parameters': {'type': 'object', 'properties': {'city': {'type': 'str', 'description': '城市名称'}}, 'required': ['city']}}, 'type': 'function'}], 'required_action': None, 'id': 'run_136ab81d-753b-4d22-bd39-8e47fc92bc74', 'object': 'thread.run', 'created_at': 1718852255073, 'thread_id': 'thread_09264327-1497-459a-8925-3a19a9081b27', 'assistant_id': 'asst_46c11acb-ea00-468b-9d42-3dd0fb3b768f', 'status': 'completed', 'last_error': None, 'expires_at': None, 'started_at': None, 'cancelled_at': None, 'failed_at': None, 'completed_at': 1718852262981, 'model': 'qwen-max', 'instructions': '你是一个旅游助手，可以通过调用插件解决问题。插件例如，天气查询，路径推荐，当地餐厅推荐等，当你无法回答问题时应当结合插件回复进行回答。请根据插件结果适当丰富回复内容。', 'file_ids': [], 'metadata': {}, 'usage': {'input_tokens': 853, 'output_tokens': 38, 'total_tokens': 891}, 'temperature': None, 'top_p': None, 'top_k': None, 'max_tokens': None, 'truncation_strategy': None, 'tool_choice': 'auto', 'request_id': '71e78fcf-74ed-9c47-a087-0a3b48cc1845', 'status_code': 200}
# 运行结果:
# content:  丽江天气怎么样？
# content:  丽江2023年4月7日的天气预报是晴朗的。如果您计划外出，记得享受那里的明媚阳光，同时也要做好防晒措施哦。

# %%
send_message(assistant=trip_agent, message="年假打算出去玩，有什么地点推荐吗")
# Out:
# Query: 年假打算出去玩，有什么地点推荐吗
# {'id': 'thread_7eb269d0-9298-46aa-92c1-a5b7f0c816db', 'object': 'thread', 'created_at': 1718852289037, 'metadata': {}, 'request_id': 'dfbd3d05-cefa-9860-a590-4b7a3c9896ff', 'status_code': 200}
# {'tools': [{'function': {'name': '天气查询', 'description': '用于查询天气的插件和函数', 'parameters': {'type': 'object', 'properties': {'location': {'type': 'str', 'description': '待查询的地点'}, 'date': {'type': 'str', 'description': '待查询的具体日期'}}, 'required': ['location', 'date']}}, 'type': 'function'}, {'function': {'name': '路径规划', 'description': '用于推荐出行和旅游的路径规划，包含查询路线，规划起点到终点的路线。也用于推荐最近最热门的旅游行程。', 'parameters': {'type': 'object', 'properties': {'start': {'type': 'str', 'description': '待查询路径规划的出发点'}, 'dest': {'type': 'str', 'description': '待查询路径规划的终点.'}, 'recommendation': {'type': 'int', 'description': '用于控制是否随机推荐，用于在无法判断有路径规划终点时，设置为1，其他情况为0。此时会推荐最热门的旅游路线.'}}, 'required': ['start', 'dest', 'recommendation']}}, 'type': 'function'}, {'function': {'name': '获取目的地建议', 'description': '用于推荐最近热门的旅游目的地。', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'str', 'description': '可能需要的信息'}}, 'required': ['query']}}, 'type': 'function'}, {'function': {'name': '获取景点推荐', 'description': '用于推荐指定城市的旅游景点。', 'parameters': {'type': 'object', 'properties': {'city': {'type': 'str', 'description': '城市名称'}}, 'required': ['city']}}, 'type': 'function'}, {'function': {'name': '获取餐饮推荐', 'description': '用于推荐指定城市的餐饮。', 'parameters': {'type': 'object', 'properties': {'city': {'type': 'str', 'description': '城市名称'}}, 'required': ['city']}}, 'type': 'function'}, {'function': {'name': '获取旅行提示', 'description': '用于获取指定城市的旅行注意事项。', 'parameters': {'type': 'object', 'properties': {'city': {'type': 'str', 'description': '城市名称'}}, 'required': ['city']}}, 'type': 'function'}, {'function': {'name': '获取当地风俗', 'description': '用于获取指定城市的当地风俗。', 'parameters': {'type': 'object', 'properties': {'city': {'type': 'str', 'description': '城市名称'}}, 'required': ['city']}}, 'type': 'function'}], 'required_action': {'submit_tool_outputs': {'tool_calls': [{'id': '', 'function': {'arguments': '{"query": "最近热门的旅游目的地"}', 'name': '获取目的地建议', 'output': None}, 'type': 'function'}]}, 'type': 'submit_tool_outputs'}, 'id': 'run_5a0bb8e6-98d9-4c31-9ad0-6e76538af2cf', 'object': 'thread.run', 'created_at': 1718852289455, 'thread_id': 'thread_7eb269d0-9298-46aa-92c1-a5b7f0c816db', 'assistant_id': 'asst_46c11acb-ea00-468b-9d42-3dd0fb3b768f', 'status': 'requires_action', 'last_error': None, 'expires_at': None, 'started_at': None, 'cancelled_at': None, 'failed_at': None, 'completed_at': 1718852291912, 'model': 'qwen-max', 'instructions': '你是一个旅游助手，可以通过调用插件解决问题。插件例如，天气查询，路径推荐，当地餐厅推荐等，当你无法回答问题时应当结合插件回复进行回答。请根据插件结果适当丰富回复内容。', 'file_ids': [], 'metadata': {}, 'usage': None, 'temperature': None, 'top_p': None, 'top_k': None, 'max_tokens': None, 'truncation_strategy': None, 'tool_choice': 'auto', 'request_id': '364c6632-00f8-9e7c-be03-0d153f63b736', 'status_code': 200}
# {
#     "assistant_id": "asst_46c11acb-ea00-468b-9d42-3dd0fb3b768f",
#     "cancelled_at": null,
#     "completed_at": 1718852291912,
#     "created_at": 1718852289455,
#     "expires_at": null,
#     "failed_at": null,
#     "file_ids": [],
#     "id": "run_5a0bb8e6-98d9-4c31-9ad0-6e76538af2cf",
#     "instructions": "\u4f60\u662f\u4e00\u4e2a\u65c5\u6e38\u52a9\u624b\uff0c\u53ef\u4ee5\u901a\u8fc7\u8c03\u7528\u63d2\u4ef6\u89e3\u51b3\u95ee\u9898\u3002\u63d2\u4ef6\u4f8b\u5982\uff0c\u5929\u6c14\u67e5\u8be2\uff0c\u8def\u5f84\u63a8\u8350\uff0c\u5f53\u5730\u9910\u5385\u63a8\u8350\u7b49\uff0c\u5f53\u4f60\u65e0\u6cd5\u56de\u7b54\u95ee\u9898\u65f6\u5e94\u5f53\u7ed3\u5408\u63d2\u4ef6\u56de\u590d\u8fdb\u884c\u56de\u7b54\u3002\u8bf7\u6839\u636e\u63d2\u4ef6\u7ed3\u679c\u9002\u5f53\u4e30\u5bcc\u56de\u590d\u5185\u5bb9\u3002",
#     "last_error": null,
#     "max_tokens": null,
#     "metadata": {},
#     "model": "qwen-max",
#     "object": "thread.run",
#     "request_id": "b5090543-1970-991c-8cda-b675c87614bc",
#     "required_action": {
#         "submit_tool_outputs": {
#             "tool_calls": [
#                 {
#                     "function": {
#                         "arguments": "{\"query\": \"\u6700\u8fd1\u70ed\u95e8\u7684\u65c5\u6e38\u76ee\u7684\u5730\"}",
#                         "name": "\u83b7\u53d6\u76ee\u7684\u5730\u5efa\u8bae"
#                     },
#                     "id": "",
#                     "type": "function"
#                 }
#             ]
#         },
#         "type": "submit_tool_outputs"
#     },
#     "started_at": null,
#     "status": "requires_action",
#     "status_code": 200,
#     "temperature": null,
#     "thread_id": "thread_7eb269d0-9298-46aa-92c1-a5b7f0c816db",
#     "tool_choice": "auto",
#     "tools": [
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u67e5\u8be2\u5929\u6c14\u7684\u63d2\u4ef6\u548c\u51fd\u6570",
#                 "name": "\u5929\u6c14\u67e5\u8be2",
#                 "parameters": {
#                     "properties": {
#                         "date": {
#                             "description": "\u5f85\u67e5\u8be2\u7684\u5177\u4f53\u65e5\u671f",
#                             "type": "str"
#                         },
#                         "location": {
#                             "description": "\u5f85\u67e5\u8be2\u7684\u5730\u70b9",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "location",
#                         "date"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         },
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u63a8\u8350\u51fa\u884c\u548c\u65c5\u6e38\u7684\u8def\u5f84\u89c4\u5212\uff0c\u5305\u542b\u67e5\u8be2\u8def\u7ebf\uff0c\u89c4\u5212\u8d77\u70b9\u5230\u7ec8\u70b9\u7684\u8def\u7ebf\u3002\u4e5f\u7528\u4e8e\u63a8\u8350\u6700\u8fd1\u6700\u70ed\u95e8\u7684\u65c5\u6e38\u884c\u7a0b\u3002",
#                 "name": "\u8def\u5f84\u89c4\u5212",
#                 "parameters": {
#                     "properties": {
#                         "dest": {
#                             "description": "\u5f85\u67e5\u8be2\u8def\u5f84\u89c4\u5212\u7684\u7ec8\u70b9.",
#                             "type": "str"
#                         },
#                         "recommendation": {
#                             "description": "\u7528\u4e8e\u63a7\u5236\u662f\u5426\u968f\u673a\u63a8\u8350\uff0c\u7528\u4e8e\u5728\u65e0\u6cd5\u5224\u65ad\u6709\u8def\u5f84\u89c4\u5212\u7ec8\u70b9\u65f6\uff0c\u8bbe\u7f6e\u4e3a1\uff0c\u5176\u4ed6\u60c5\u51b5\u4e3a0\u3002\u6b64\u65f6\u4f1a\u63a8\u8350\u6700\u70ed\u95e8\u7684\u65c5\u6e38\u8def\u7ebf.",
#                             "type": "int"
#                         },
#                         "start": {
#                             "description": "\u5f85\u67e5\u8be2\u8def\u5f84\u89c4\u5212\u7684\u51fa\u53d1\u70b9",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "start",
#                         "dest",
#                         "recommendation"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         },
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u63a8\u8350\u6700\u8fd1\u70ed\u95e8\u7684\u65c5\u6e38\u76ee\u7684\u5730\u3002",
#                 "name": "\u83b7\u53d6\u76ee\u7684\u5730\u5efa\u8bae",
#                 "parameters": {
#                     "properties": {
#                         "query": {
#                             "description": "\u53ef\u80fd\u9700\u8981\u7684\u4fe1\u606f",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "query"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         },
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u63a8\u8350\u6307\u5b9a\u57ce\u5e02\u7684\u65c5\u6e38\u666f\u70b9\u3002",
#                 "name": "\u83b7\u53d6\u666f\u70b9\u63a8\u8350",
#                 "parameters": {
#                     "properties": {
#                         "city": {
#                             "description": "\u57ce\u5e02\u540d\u79f0",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "city"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         },
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u63a8\u8350\u6307\u5b9a\u57ce\u5e02\u7684\u9910\u996e\u3002",
#                 "name": "\u83b7\u53d6\u9910\u996e\u63a8\u8350",
#                 "parameters": {
#                     "properties": {
#                         "city": {
#                             "description": "\u57ce\u5e02\u540d\u79f0",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "city"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         },
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u83b7\u53d6\u6307\u5b9a\u57ce\u5e02\u7684\u65c5\u884c\u6ce8\u610f\u4e8b\u9879\u3002",
#                 "name": "\u83b7\u53d6\u65c5\u884c\u63d0\u793a",
#                 "parameters": {
#                     "properties": {
#                         "city": {
#                             "description": "\u57ce\u5e02\u540d\u79f0",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "city"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         },
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u83b7\u53d6\u6307\u5b9a\u57ce\u5e02\u7684\u5f53\u5730\u98ce\u4fd7\u3002",
#                 "name": "\u83b7\u53d6\u5f53\u5730\u98ce\u4fd7",
#                 "parameters": {
#                     "properties": {
#                         "city": {
#                             "description": "\u57ce\u5e02\u540d\u79f0",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "city"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         }
#     ],
#     "top_k": null,
#     "top_p": null,
#     "truncation_strategy": null,
#     "usage": null
# }
# {'name': '获取目的地建议', 'arguments': '{"query": "最近热门的旅游目的地"}', 'output': None}
# 根
# 根据近期的热门程度
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    -
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽。
#    - **束河古镇**
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽。
#    - **束河古镇**：更加宁静的环境，适合慢慢
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽。
#    - **束河古镇**：更加宁静的环境，适合慢慢品味茶香，享受悠闲时光。
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽。
#    - **束河古镇**：更加宁静的环境，适合慢慢品味茶香，享受悠闲时光。
#
# 3. **巴黎, 法国
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽。
#    - **束河古镇**：更加宁静的环境，适合慢慢品味茶香，享受悠闲时光。
#
# 3. **巴黎, 法国**:
#    - **埃菲尔铁
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽。
#    - **束河古镇**：更加宁静的环境，适合慢慢品味茶香，享受悠闲时光。
#
# 3. **巴黎, 法国**:
#    - **埃菲尔铁塔**：登顶铁塔，
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽。
#    - **束河古镇**：更加宁静的环境，适合慢慢品味茶香，享受悠闲时光。
#
# 3. **巴黎, 法国**:
#    - **埃菲尔铁塔**：登顶铁塔，将巴黎的浪漫景致尽收
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽。
#    - **束河古镇**：更加宁静的环境，适合慢慢品味茶香，享受悠闲时光。
#
# 3. **巴黎, 法国**:
#    - **埃菲尔铁塔**：登顶铁塔，将巴黎的浪漫景致尽收眼底。
#    - **卢浮
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽。
#    - **束河古镇**：更加宁静的环境，适合慢慢品味茶香，享受悠闲时光。
#
# 3. **巴黎, 法国**:
#    - **埃菲尔铁塔**：登顶铁塔，将巴黎的浪漫景致尽收眼底。
#    - **卢浮宫**：艺术爱好者的圣地，
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽。
#    - **束河古镇**：更加宁静的环境，适合慢慢品味茶香，享受悠闲时光。
#
# 3. **巴黎, 法国**:
#    - **埃菲尔铁塔**：登顶铁塔，将巴黎的浪漫景致尽收眼底。
#    - **卢浮宫**：艺术爱好者的圣地，亲眼目睹《蒙娜丽莎》
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽。
#    - **束河古镇**：更加宁静的环境，适合慢慢品味茶香，享受悠闲时光。
#
# 3. **巴黎, 法国**:
#    - **埃菲尔铁塔**：登顶铁塔，将巴黎的浪漫景致尽收眼底。
#    - **卢浮宫**：艺术爱好者的圣地，亲眼目睹《蒙娜丽莎》的微笑。
#    - **凡尔
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽。
#    - **束河古镇**：更加宁静的环境，适合慢慢品味茶香，享受悠闲时光。
#
# 3. **巴黎, 法国**:
#    - **埃菲尔铁塔**：登顶铁塔，将巴黎的浪漫景致尽收眼底。
#    - **卢浮宫**：艺术爱好者的圣地，亲眼目睹《蒙娜丽莎》的微笑。
#    - **凡尔赛宫**：金碧辉煌的
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽。
#    - **束河古镇**：更加宁静的环境，适合慢慢品味茶香，享受悠闲时光。
#
# 3. **巴黎, 法国**:
#    - **埃菲尔铁塔**：登顶铁塔，将巴黎的浪漫景致尽收眼底。
#    - **卢浮宫**：艺术爱好者的圣地，亲眼目睹《蒙娜丽莎》的微笑。
#    - **凡尔赛宫**：金碧辉煌的宫殿和广阔的园林，展现了法国王
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽。
#    - **束河古镇**：更加宁静的环境，适合慢慢品味茶香，享受悠闲时光。
#
# 3. **巴黎, 法国**:
#    - **埃菲尔铁塔**：登顶铁塔，将巴黎的浪漫景致尽收眼底。
#    - **卢浮宫**：艺术爱好者的圣地，亲眼目睹《蒙娜丽莎》的微笑。
#    - **凡尔赛宫**：金碧辉煌的宫殿和广阔的园林，展现了法国王室的奢华。
#
# 4. **开
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽。
#    - **束河古镇**：更加宁静的环境，适合慢慢品味茶香，享受悠闲时光。
#
# 3. **巴黎, 法国**:
#    - **埃菲尔铁塔**：登顶铁塔，将巴黎的浪漫景致尽收眼底。
#    - **卢浮宫**：艺术爱好者的圣地，亲眼目睹《蒙娜丽莎》的微笑。
#    - **凡尔赛宫**：金碧辉煌的宫殿和广阔的园林，展现了法国王室的奢华。
#
# 4. **开普敦, 南非**:
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽。
#    - **束河古镇**：更加宁静的环境，适合慢慢品味茶香，享受悠闲时光。
#
# 3. **巴黎, 法国**:
#    - **埃菲尔铁塔**：登顶铁塔，将巴黎的浪漫景致尽收眼底。
#    - **卢浮宫**：艺术爱好者的圣地，亲眼目睹《蒙娜丽莎》的微笑。
#    - **凡尔赛宫**：金碧辉煌的宫殿和广阔的园林，展现了法国王室的奢华。
#
# 4. **开普敦, 南非**:
#    - **桌山**：乘坐
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽。
#    - **束河古镇**：更加宁静的环境，适合慢慢品味茶香，享受悠闲时光。
#
# 3. **巴黎, 法国**:
#    - **埃菲尔铁塔**：登顶铁塔，将巴黎的浪漫景致尽收眼底。
#    - **卢浮宫**：艺术爱好者的圣地，亲眼目睹《蒙娜丽莎》的微笑。
#    - **凡尔赛宫**：金碧辉煌的宫殿和广阔的园林，展现了法国王室的奢华。
#
# 4. **开普敦, 南非**:
#    - **桌山**：乘坐缆车登顶，俯瞰整个
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽。
#    - **束河古镇**：更加宁静的环境，适合慢慢品味茶香，享受悠闲时光。
#
# 3. **巴黎, 法国**:
#    - **埃菲尔铁塔**：登顶铁塔，将巴黎的浪漫景致尽收眼底。
#    - **卢浮宫**：艺术爱好者的圣地，亲眼目睹《蒙娜丽莎》的微笑。
#    - **凡尔赛宫**：金碧辉煌的宫殿和广阔的园林，展现了法国王室的奢华。
#
# 4. **开普敦, 南非**:
#    - **桌山**：乘坐缆车登顶，俯瞰整个开普敦的迷人景色。
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽。
#    - **束河古镇**：更加宁静的环境，适合慢慢品味茶香，享受悠闲时光。
#
# 3. **巴黎, 法国**:
#    - **埃菲尔铁塔**：登顶铁塔，将巴黎的浪漫景致尽收眼底。
#    - **卢浮宫**：艺术爱好者的圣地，亲眼目睹《蒙娜丽莎》的微笑。
#    - **凡尔赛宫**：金碧辉煌的宫殿和广阔的园林，展现了法国王室的奢华。
#
# 4. **开普敦, 南非**:
#    - **桌山**：乘坐缆车登顶，俯瞰整个开普敦的迷人景色。
#    - **好望角**：站在
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽。
#    - **束河古镇**：更加宁静的环境，适合慢慢品味茶香，享受悠闲时光。
#
# 3. **巴黎, 法国**:
#    - **埃菲尔铁塔**：登顶铁塔，将巴黎的浪漫景致尽收眼底。
#    - **卢浮宫**：艺术爱好者的圣地，亲眼目睹《蒙娜丽莎》的微笑。
#    - **凡尔赛宫**：金碧辉煌的宫殿和广阔的园林，展现了法国王室的奢华。
#
# 4. **开普敦, 南非**:
#    - **桌山**：乘坐缆车登顶，俯瞰整个开普敦的迷人景色。
#    - **好望角**：站在非洲大陆的最南端，感受
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽。
#    - **束河古镇**：更加宁静的环境，适合慢慢品味茶香，享受悠闲时光。
#
# 3. **巴黎, 法国**:
#    - **埃菲尔铁塔**：登顶铁塔，将巴黎的浪漫景致尽收眼底。
#    - **卢浮宫**：艺术爱好者的圣地，亲眼目睹《蒙娜丽莎》的微笑。
#    - **凡尔赛宫**：金碧辉煌的宫殿和广阔的园林，展现了法国王室的奢华。
#
# 4. **开普敦, 南非**:
#    - **桌山**：乘坐缆车登顶，俯瞰整个开普敦的迷人景色。
#    - **好望角**：站在非洲大陆的最南端，感受大航海时代的探险精神。
#    -
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽。
#    - **束河古镇**：更加宁静的环境，适合慢慢品味茶香，享受悠闲时光。
#
# 3. **巴黎, 法国**:
#    - **埃菲尔铁塔**：登顶铁塔，将巴黎的浪漫景致尽收眼底。
#    - **卢浮宫**：艺术爱好者的圣地，亲眼目睹《蒙娜丽莎》的微笑。
#    - **凡尔赛宫**：金碧辉煌的宫殿和广阔的园林，展现了法国王室的奢华。
#
# 4. **开普敦, 南非**:
#    - **桌山**：乘坐缆车登顶，俯瞰整个开普敦的迷人景色。
#    - **好望角**：站在非洲大陆的最南端，感受大航海时代的探险精神。
#    - **克尔斯滕博施植物园
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽。
#    - **束河古镇**：更加宁静的环境，适合慢慢品味茶香，享受悠闲时光。
#
# 3. **巴黎, 法国**:
#    - **埃菲尔铁塔**：登顶铁塔，将巴黎的浪漫景致尽收眼底。
#    - **卢浮宫**：艺术爱好者的圣地，亲眼目睹《蒙娜丽莎》的微笑。
#    - **凡尔赛宫**：金碧辉煌的宫殿和广阔的园林，展现了法国王室的奢华。
#
# 4. **开普敦, 南非**:
#    - **桌山**：乘坐缆车登顶，俯瞰整个开普敦的迷人景色。
#    - **好望角**：站在非洲大陆的最南端，感受大航海时代的探险精神。
#    - **克尔斯滕博施植物园**：世界上独一无二的植物种类，
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽。
#    - **束河古镇**：更加宁静的环境，适合慢慢品味茶香，享受悠闲时光。
#
# 3. **巴黎, 法国**:
#    - **埃菲尔铁塔**：登顶铁塔，将巴黎的浪漫景致尽收眼底。
#    - **卢浮宫**：艺术爱好者的圣地，亲眼目睹《蒙娜丽莎》的微笑。
#    - **凡尔赛宫**：金碧辉煌的宫殿和广阔的园林，展现了法国王室的奢华。
#
# 4. **开普敦, 南非**:
#    - **桌山**：乘坐缆车登顶，俯瞰整个开普敦的迷人景色。
#    - **好望角**：站在非洲大陆的最南端，感受大航海时代的探险精神。
#    - **克尔斯滕博施植物园**：世界上独一无二的植物种类，让您置身于自然的宝库之中
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽。
#    - **束河古镇**：更加宁静的环境，适合慢慢品味茶香，享受悠闲时光。
#
# 3. **巴黎, 法国**:
#    - **埃菲尔铁塔**：登顶铁塔，将巴黎的浪漫景致尽收眼底。
#    - **卢浮宫**：艺术爱好者的圣地，亲眼目睹《蒙娜丽莎》的微笑。
#    - **凡尔赛宫**：金碧辉煌的宫殿和广阔的园林，展现了法国王室的奢华。
#
# 4. **开普敦, 南非**:
#    - **桌山**：乘坐缆车登顶，俯瞰整个开普敦的迷人景色。
#    - **好望角**：站在非洲大陆的最南端，感受大航海时代的探险精神。
#    - **克尔斯滕博施植物园**：世界上独一无二的植物种类，让您置身于自然的宝库之中。
#
# 每个地方都有其独特的魅力和
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽。
#    - **束河古镇**：更加宁静的环境，适合慢慢品味茶香，享受悠闲时光。
#
# 3. **巴黎, 法国**:
#    - **埃菲尔铁塔**：登顶铁塔，将巴黎的浪漫景致尽收眼底。
#    - **卢浮宫**：艺术爱好者的圣地，亲眼目睹《蒙娜丽莎》的微笑。
#    - **凡尔赛宫**：金碧辉煌的宫殿和广阔的园林，展现了法国王室的奢华。
#
# 4. **开普敦, 南非**:
#    - **桌山**：乘坐缆车登顶，俯瞰整个开普敦的迷人景色。
#    - **好望角**：站在非洲大陆的最南端，感受大航海时代的探险精神。
#    - **克尔斯滕博施植物园**：世界上独一无二的植物种类，让您置身于自然的宝库之中。
#
# 每个地方都有其独特的魅力和丰富的活动，可以根据您的兴趣和假期
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽。
#    - **束河古镇**：更加宁静的环境，适合慢慢品味茶香，享受悠闲时光。
#
# 3. **巴黎, 法国**:
#    - **埃菲尔铁塔**：登顶铁塔，将巴黎的浪漫景致尽收眼底。
#    - **卢浮宫**：艺术爱好者的圣地，亲眼目睹《蒙娜丽莎》的微笑。
#    - **凡尔赛宫**：金碧辉煌的宫殿和广阔的园林，展现了法国王室的奢华。
#
# 4. **开普敦, 南非**:
#    - **桌山**：乘坐缆车登顶，俯瞰整个开普敦的迷人景色。
#    - **好望角**：站在非洲大陆的最南端，感受大航海时代的探险精神。
#    - **克尔斯滕博施植物园**：世界上独一无二的植物种类，让您置身于自然的宝库之中。
#
# 每个地方都有其独特的魅力和丰富的活动，可以根据您的兴趣和假期安排来选择。希望这些建
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽。
#    - **束河古镇**：更加宁静的环境，适合慢慢品味茶香，享受悠闲时光。
#
# 3. **巴黎, 法国**:
#    - **埃菲尔铁塔**：登顶铁塔，将巴黎的浪漫景致尽收眼底。
#    - **卢浮宫**：艺术爱好者的圣地，亲眼目睹《蒙娜丽莎》的微笑。
#    - **凡尔赛宫**：金碧辉煌的宫殿和广阔的园林，展现了法国王室的奢华。
#
# 4. **开普敦, 南非**:
#    - **桌山**：乘坐缆车登顶，俯瞰整个开普敦的迷人景色。
#    - **好望角**：站在非洲大陆的最南端，感受大航海时代的探险精神。
#    - **克尔斯滕博施植物园**：世界上独一无二的植物种类，让您置身于自然的宝库之中。
#
# 每个地方都有其独特的魅力和丰富的活动，可以根据您的兴趣和假期安排来选择。希望这些建议能帮助您规划一个难忘的
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽。
#    - **束河古镇**：更加宁静的环境，适合慢慢品味茶香，享受悠闲时光。
#
# 3. **巴黎, 法国**:
#    - **埃菲尔铁塔**：登顶铁塔，将巴黎的浪漫景致尽收眼底。
#    - **卢浮宫**：艺术爱好者的圣地，亲眼目睹《蒙娜丽莎》的微笑。
#    - **凡尔赛宫**：金碧辉煌的宫殿和广阔的园林，展现了法国王室的奢华。
#
# 4. **开普敦, 南非**:
#    - **桌山**：乘坐缆车登顶，俯瞰整个开普敦的迷人景色。
#    - **好望角**：站在非洲大陆的最南端，感受大航海时代的探险精神。
#    - **克尔斯滕博施植物园**：世界上独一无二的植物种类，让您置身于自然的宝库之中。
#
# 每个地方都有其独特的魅力和丰富的活动，可以根据您的兴趣和假期安排来选择。希望这些建议能帮助您规划一个难忘的年假旅行！
# 根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽。
#    - **束河古镇**：更加宁静的环境，适合慢慢品味茶香，享受悠闲时光。
#
# 3. **巴黎, 法国**:
#    - **埃菲尔铁塔**：登顶铁塔，将巴黎的浪漫景致尽收眼底。
#    - **卢浮宫**：艺术爱好者的圣地，亲眼目睹《蒙娜丽莎》的微笑。
#    - **凡尔赛宫**：金碧辉煌的宫殿和广阔的园林，展现了法国王室的奢华。
#
# 4. **开普敦, 南非**:
#    - **桌山**：乘坐缆车登顶，俯瞰整个开普敦的迷人景色。
#    - **好望角**：站在非洲大陆的最南端，感受大航海时代的探险精神。
#    - **克尔斯滕博施植物园**：世界上独一无二的植物种类，让您置身于自然的宝库之中。
#
# 每个地方都有其独特的魅力和丰富的活动，可以根据您的兴趣和假期安排来选择。希望这些建议能帮助您规划一个难忘的年假旅行！
# {
#     "assistant_id": "asst_46c11acb-ea00-468b-9d42-3dd0fb3b768f",
#     "cancelled_at": null,
#     "completed_at": 1718852327001,
#     "created_at": 1718852289455,
#     "expires_at": null,
#     "failed_at": null,
#     "file_ids": [],
#     "id": "run_5a0bb8e6-98d9-4c31-9ad0-6e76538af2cf",
#     "instructions": "\u4f60\u662f\u4e00\u4e2a\u65c5\u6e38\u52a9\u624b\uff0c\u53ef\u4ee5\u901a\u8fc7\u8c03\u7528\u63d2\u4ef6\u89e3\u51b3\u95ee\u9898\u3002\u63d2\u4ef6\u4f8b\u5982\uff0c\u5929\u6c14\u67e5\u8be2\uff0c\u8def\u5f84\u63a8\u8350\uff0c\u5f53\u5730\u9910\u5385\u63a8\u8350\u7b49\uff0c\u5f53\u4f60\u65e0\u6cd5\u56de\u7b54\u95ee\u9898\u65f6\u5e94\u5f53\u7ed3\u5408\u63d2\u4ef6\u56de\u590d\u8fdb\u884c\u56de\u7b54\u3002\u8bf7\u6839\u636e\u63d2\u4ef6\u7ed3\u679c\u9002\u5f53\u4e30\u5bcc\u56de\u590d\u5185\u5bb9\u3002",
#     "last_error": null,
#     "max_tokens": null,
#     "metadata": {},
#     "model": "qwen-max",
#     "object": "thread.run",
#     "request_id": "00b3188a-2f48-99ed-bde5-d99778aa6fd8",
#     "required_action": null,
#     "started_at": null,
#     "status": "completed",
#     "status_code": 200,
#     "temperature": null,
#     "thread_id": "thread_7eb269d0-9298-46aa-92c1-a5b7f0c816db",
#     "tool_choice": "auto",
#     "tools": [
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u67e5\u8be2\u5929\u6c14\u7684\u63d2\u4ef6\u548c\u51fd\u6570",
#                 "name": "\u5929\u6c14\u67e5\u8be2",
#                 "parameters": {
#                     "properties": {
#                         "date": {
#                             "description": "\u5f85\u67e5\u8be2\u7684\u5177\u4f53\u65e5\u671f",
#                             "type": "str"
#                         },
#                         "location": {
#                             "description": "\u5f85\u67e5\u8be2\u7684\u5730\u70b9",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "location",
#                         "date"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         },
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u63a8\u8350\u51fa\u884c\u548c\u65c5\u6e38\u7684\u8def\u5f84\u89c4\u5212\uff0c\u5305\u542b\u67e5\u8be2\u8def\u7ebf\uff0c\u89c4\u5212\u8d77\u70b9\u5230\u7ec8\u70b9\u7684\u8def\u7ebf\u3002\u4e5f\u7528\u4e8e\u63a8\u8350\u6700\u8fd1\u6700\u70ed\u95e8\u7684\u65c5\u6e38\u884c\u7a0b\u3002",
#                 "name": "\u8def\u5f84\u89c4\u5212",
#                 "parameters": {
#                     "properties": {
#                         "dest": {
#                             "description": "\u5f85\u67e5\u8be2\u8def\u5f84\u89c4\u5212\u7684\u7ec8\u70b9.",
#                             "type": "str"
#                         },
#                         "recommendation": {
#                             "description": "\u7528\u4e8e\u63a7\u5236\u662f\u5426\u968f\u673a\u63a8\u8350\uff0c\u7528\u4e8e\u5728\u65e0\u6cd5\u5224\u65ad\u6709\u8def\u5f84\u89c4\u5212\u7ec8\u70b9\u65f6\uff0c\u8bbe\u7f6e\u4e3a1\uff0c\u5176\u4ed6\u60c5\u51b5\u4e3a0\u3002\u6b64\u65f6\u4f1a\u63a8\u8350\u6700\u70ed\u95e8\u7684\u65c5\u6e38\u8def\u7ebf.",
#                             "type": "int"
#                         },
#                         "start": {
#                             "description": "\u5f85\u67e5\u8be2\u8def\u5f84\u89c4\u5212\u7684\u51fa\u53d1\u70b9",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "start",
#                         "dest",
#                         "recommendation"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         },
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u63a8\u8350\u6700\u8fd1\u70ed\u95e8\u7684\u65c5\u6e38\u76ee\u7684\u5730\u3002",
#                 "name": "\u83b7\u53d6\u76ee\u7684\u5730\u5efa\u8bae",
#                 "parameters": {
#                     "properties": {
#                         "query": {
#                             "description": "\u53ef\u80fd\u9700\u8981\u7684\u4fe1\u606f",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "query"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         },
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u63a8\u8350\u6307\u5b9a\u57ce\u5e02\u7684\u65c5\u6e38\u666f\u70b9\u3002",
#                 "name": "\u83b7\u53d6\u666f\u70b9\u63a8\u8350",
#                 "parameters": {
#                     "properties": {
#                         "city": {
#                             "description": "\u57ce\u5e02\u540d\u79f0",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "city"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         },
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u63a8\u8350\u6307\u5b9a\u57ce\u5e02\u7684\u9910\u996e\u3002",
#                 "name": "\u83b7\u53d6\u9910\u996e\u63a8\u8350",
#                 "parameters": {
#                     "properties": {
#                         "city": {
#                             "description": "\u57ce\u5e02\u540d\u79f0",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "city"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         },
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u83b7\u53d6\u6307\u5b9a\u57ce\u5e02\u7684\u65c5\u884c\u6ce8\u610f\u4e8b\u9879\u3002",
#                 "name": "\u83b7\u53d6\u65c5\u884c\u63d0\u793a",
#                 "parameters": {
#                     "properties": {
#                         "city": {
#                             "description": "\u57ce\u5e02\u540d\u79f0",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "city"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         },
#         {
#             "function": {
#                 "description": "\u7528\u4e8e\u83b7\u53d6\u6307\u5b9a\u57ce\u5e02\u7684\u5f53\u5730\u98ce\u4fd7\u3002",
#                 "name": "\u83b7\u53d6\u5f53\u5730\u98ce\u4fd7",
#                 "parameters": {
#                     "properties": {
#                         "city": {
#                             "description": "\u57ce\u5e02\u540d\u79f0",
#                             "type": "str"
#                         }
#                     },
#                     "required": [
#                         "city"
#                     ],
#                     "type": "object"
#                 }
#             },
#             "type": "function"
#         }
#     ],
#     "top_k": null,
#     "top_p": null,
#     "truncation_strategy": null,
#     "usage": {
#         "input_tokens": 1094,
#         "output_tokens": 388,
#         "total_tokens": 1482
#     }
# }
# {'tools': [{'function': {'name': '天气查询', 'description': '用于查询天气的插件和函数', 'parameters': {'type': 'object', 'properties': {'location': {'type': 'str', 'description': '待查询的地点'}, 'date': {'type': 'str', 'description': '待查询的具体日期'}}, 'required': ['location', 'date']}}, 'type': 'function'}, {'function': {'name': '路径规划', 'description': '用于推荐出行和旅游的路径规划，包含查询路线，规划起点到终点的路线。也用于推荐最近最热门的旅游行程。', 'parameters': {'type': 'object', 'properties': {'start': {'type': 'str', 'description': '待查询路径规划的出发点'}, 'dest': {'type': 'str', 'description': '待查询路径规划的终点.'}, 'recommendation': {'type': 'int', 'description': '用于控制是否随机推荐，用于在无法判断有路径规划终点时，设置为1，其他情况为0。此时会推荐最热门的旅游路线.'}}, 'required': ['start', 'dest', 'recommendation']}}, 'type': 'function'}, {'function': {'name': '获取目的地建议', 'description': '用于推荐最近热门的旅游目的地。', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'str', 'description': '可能需要的信息'}}, 'required': ['query']}}, 'type': 'function'}, {'function': {'name': '获取景点推荐', 'description': '用于推荐指定城市的旅游景点。', 'parameters': {'type': 'object', 'properties': {'city': {'type': 'str', 'description': '城市名称'}}, 'required': ['city']}}, 'type': 'function'}, {'function': {'name': '获取餐饮推荐', 'description': '用于推荐指定城市的餐饮。', 'parameters': {'type': 'object', 'properties': {'city': {'type': 'str', 'description': '城市名称'}}, 'required': ['city']}}, 'type': 'function'}, {'function': {'name': '获取旅行提示', 'description': '用于获取指定城市的旅行注意事项。', 'parameters': {'type': 'object', 'properties': {'city': {'type': 'str', 'description': '城市名称'}}, 'required': ['city']}}, 'type': 'function'}, {'function': {'name': '获取当地风俗', 'description': '用于获取指定城市的当地风俗。', 'parameters': {'type': 'object', 'properties': {'city': {'type': 'str', 'description': '城市名称'}}, 'required': ['city']}}, 'type': 'function'}], 'required_action': None, 'id': 'run_5a0bb8e6-98d9-4c31-9ad0-6e76538af2cf', 'object': 'thread.run', 'created_at': 1718852289455, 'thread_id': 'thread_7eb269d0-9298-46aa-92c1-a5b7f0c816db', 'assistant_id': 'asst_46c11acb-ea00-468b-9d42-3dd0fb3b768f', 'status': 'completed', 'last_error': None, 'expires_at': None, 'started_at': None, 'cancelled_at': None, 'failed_at': None, 'completed_at': 1718852327001, 'model': 'qwen-max', 'instructions': '你是一个旅游助手，可以通过调用插件解决问题。插件例如，天气查询，路径推荐，当地餐厅推荐等，当你无法回答问题时应当结合插件回复进行回答。请根据插件结果适当丰富回复内容。', 'file_ids': [], 'metadata': {}, 'usage': {'input_tokens': 1094, 'output_tokens': 388, 'total_tokens': 1482}, 'temperature': None, 'top_p': None, 'top_k': None, 'max_tokens': None, 'truncation_strategy': None, 'tool_choice': 'auto', 'request_id': 'e4db3719-8e67-9f46-b23c-68d515170972', 'status_code': 200}
# 运行结果:
# content:  年假打算出去玩，有什么地点推荐吗
# content:  根据近期的热门程度，我为您推荐以下几个旅游目的地：
#
# 1. **杭州, 中国**:
#    - **西湖**：这里被誉为“人间天堂”，是中国风景最美的地方之一，您可以乘船游湖，享受如画的山水风光。
#    - **灵隐寺**：体验幽静的古刹氛围，感受历史悠久的佛教文化。
#    - **西溪湿地**：亲近自然，观察丰富的野生动植物，是远离都市喧嚣的好去处。
#
# 2. **丽江, 中国**:
#    - **丽江古城**：漫步在石板路上，探索纳西族的悠久历史与独特文化。
#    - **玉龙雪山**：无论是远观还是登山，都能领略到雪山的巍峨壮丽。
#    - **束河古镇**：更加宁静的环境，适合慢慢品味茶香，享受悠闲时光。
#
# 3. **巴黎, 法国**:
#    - **埃菲尔铁塔**：登顶铁塔，将巴黎的浪漫景致尽收眼底。
#    - **卢浮宫**：艺术爱好者的圣地，亲眼目睹《蒙娜丽莎》的微笑。
#    - **凡尔赛宫**：金碧辉煌的宫殿和广阔的园林，展现了法国王室的奢华。
#
# 4. **开普敦, 南非**:
#    - **桌山**：乘坐缆车登顶，俯瞰整个开普敦的迷人景色。
#    - **好望角**：站在非洲大陆的最南端，感受大航海时代的探险精神。
#    - **克尔斯滕博施植物园**：世界上独一无二的植物种类，让您置身于自然的宝库之中。
#
# 每个地方都有其独特的魅力和丰富的活动，可以根据您的兴趣和假期安排来选择。希望这些建议能帮助您规划一个难忘的年假旅行！

# %%
send_message(assistant=trip_agent, message="从北京去丽江怎么出行方便？")
send_message(assistant=trip_agent, message="丽江有什么好玩的地方？")
send_message(assistant=trip_agent, message="我喜欢吃，丽江有什么美食推荐吗")
send_message(assistant=trip_agent, message="去丽江还应该注意什么？")
send_message(assistant=trip_agent, message="能告诉我丽江当地有什么风俗吗")
send_message(assistant=trip_agent, message='从杭州到北京的出行推荐')
